# %%
import numpy as np
import pandas as pd 
import polars as pl

import tensorflow as tf

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OrdinalEncoder, OneHotEncoder

from lightbgm import LGBMRegressor
from xgboost import XGBRegressor
from sklearn.mulioutput import MultiOutputRegressor
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor

# %%
# %%time 

de_train_pq = pl.scan_parquet()
de_train_df = de_train_pq.collect().to_pandas()

adata_train_pq = pl.scan_parquet()

multiome_train = pl.scan_parquet()

# %%
print(de_train.columns)
print(adata_train.columns)
print(multiome_train.columns)

# %%
adata_obs_meta_pq = pl.scan_csv('')
adata_obs_meta_df = adata_obs_meta_pq.collect().to_pandas()

id_map_pq = pl.scan_csv()
id_map_df = id_map_pq.collect().to_pandas()

multiome_obs_meta_pq = pl.scan_csv()
multiome_obs_meta_df = multiome_obs_meta.collect().to_pandas()

multiome_var_meta_pq = pl.scan_csv('')
multiome_var_meta_df = multiome_var_meta_pq.collect().to_pandas()

# %%
print(adata_obs_meta_df.columns)
print(id_map_df.columns)
print(multiome_obs_meta_df.columns)
print(multiome_var_meta_df.columns)

# %%
de_train_df.head()

# %%
features = ['cell_type', 'sm_name', 'sm_lincs_id',
           'SMILES', 'control']
de_train_df_sub = de_train_df[features]

# %%
de_train_df_sub.info()

# %%
de_train_df_sub.apply(lambda x: len(x.unique()))

# %%
cell_types = de_train_df_sub.cell_type.value_counts()
sm_namea = de_train_df_sub.sm_namea.value_counts()
sm_lincs_ida = de_train_df_sub.sm_lincs_id.value_counts()
SMILESa = de_train_df_sub.SMILES.value_counts()
controls = de_train_df_sub.control.value_counts()

# %%
plt.figure(figsize=(8,2))
sns.barplot(x=cell_types.values, y = cell_types.index, color = 'g')
